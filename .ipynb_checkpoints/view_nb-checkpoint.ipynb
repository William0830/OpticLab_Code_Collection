# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import scan_plot_and_analysis as spa
# %matplotlib notebook

# %%
scan_name = r'C:\Users\spmno\OneDrive\Documents\spm\test4\Scan Data\2023-08-02\2023-08-02_MH-01-17_DropCast_2_scan_data.txt'

Xs, Ys, Ts, CH1_ints, CH2_ints = spa.load_scan_data(100, 100, 0.5, scan_name)

# %%
spa.plot_int_heatmap(Xs, Ys, CH1_ints, size=(8, 8), save=False, save_name='scan.png')
# Out:
# <img src="data:image/png;base64,..." width="800">
